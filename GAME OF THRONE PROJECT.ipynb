# %%
import pandas as pd

# %%
battle=pd.read_csv(r"C:\Users\Vivek\Desktop\GAME _OF_THRONE_DATASET\battles.csv")
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
# ...

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # ATTACKER SIZE VS DEFENDER SIZE

# %%
battle.plot.bar(x= 'defender_size',y="attacker_size" )
plt.xlabel("defender_size")
plt.ylabel("attacker_size")
# Out:
# Text(0, 0.5, 'attacker_size')

# %% [markdown]
# # REGION

# %%
ab=battle.groupby("region")["region"].count() 
ab
# Out:
# region
# Beyond the Wall     1
# The Crownlands      2
# The North          10
# The Reach           2
# The Riverlands     17
# The Stormlands      3
# The Westerlands     3
# Name: region, dtype: int64

# %%
REGION=plt.pie(x=[1,2,10,2,17,3,3],labels=['Beyond the Wall','The Crownlands','The North','The Reach','The Riverlands','The Stormlands','The Westerlands'])
REGION
# Out:
# ([<matplotlib.patches.Wedge at 0x1baf5c70cd0>,
# ...
#  [Text(1.0962429422513844, 0.09083728069481341, 'Beyond the Wall'),
#   Text(1.0403989649906822, 0.3571694186885514, 'The Crownlands'),
#   Text(0.2700340003861216, 1.0663403015151722, 'The North'),
#   Text(-0.7450097806321688, 0.8092962540148124, 'The Reach'),
#   Text(-0.8092962714530249, -0.7450097616892225, 'The Riverlands'),
#   Text(0.8092963063294473, -0.7450097238033296, 'The Stormlands'),
#   Text(1.066340288873967, -0.2700340503051134, 'The Westerlands')])

# %% [markdown]
# # BATTLE TYPE

# %%
battle.battle_type.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # TRANSFORMED DATA

# %%
battle1=battle[['battle_type','attacker_size','defender_size','location','region','attacker_outcome']]
battle1
# Out:
#        battle_type  attacker_size  defender_size  \
# 0   pitched battle        15000.0         4000.0
# 1           ambush            NaN          120.0
# 2   pitched battle        15000.0        10000.0
# 3   pitched battle        18000.0        20000.0
# 4           ambush         1875.0         6000.0
# 5           ambush         6000.0        12625.0
# 6   pitched battle            NaN            NaN
# 7   pitched battle            NaN            NaN
# 8            siege         1000.0            NaN
# 9           ambush          264.0            NaN
# 10  pitched battle          244.0          900.0
# 11          ambush           20.0            NaN
# 12           siege            NaN            NaN
# 13          ambush          618.0         2000.0
# 14          ambush         6000.0        10000.0
# 15           siege         5000.0        20000.0
# 16  pitched battle        20000.0        10000.0
# 17          ambush          100.0          100.0
# ...

# %%
battle1=battle1.fillna(method="pad")
battle1
# Out:
#        battle_type  attacker_size  defender_size  \
# 0   pitched battle        15000.0         4000.0
# 1           ambush        15000.0          120.0
# 2   pitched battle        15000.0        10000.0
# 3   pitched battle        18000.0        20000.0
# 4           ambush         1875.0         6000.0
# 5           ambush         6000.0        12625.0
# 6   pitched battle         6000.0        12625.0
# 7   pitched battle         6000.0        12625.0
# 8            siege         1000.0        12625.0
# 9           ambush          264.0        12625.0
# 10  pitched battle          244.0          900.0
# 11          ambush           20.0          900.0
# 12           siege           20.0          900.0
# 13          ambush          618.0         2000.0
# 14          ambush         6000.0        10000.0
# 15           siege         5000.0        20000.0
# 16  pitched battle        20000.0        10000.0
# 17          ambush          100.0          100.0
# ...

# %%
battle1.to_csv('battle1.csv', index=False)

# %% [markdown]
# # CONNECTION FOR  AWS LAMBDA TO CONNECT TO S3  AND  RDS

# %%
    bucket = event
    bucket = event['Records'][0]['s3']['bucket']['name']
    csv_file = event['Records'][0]['s3']['object']['key']
    response = s3client.get_object(Bucket=bucket, Key=csv_file)
    lines = response['Body'].read().decode('utf-8').split()
    results = []
    for row in csv.DictReader(lines):
        results.append(row.values())
    print(results)
    connection = mysql.connector.connect(host='task3database.cbaouc4e4ks8.us-east-1.rds.amazonaws.com',
                                         database='GOT',
                                         user='admin',
                                         passwd='ant966AA')
    mysql_insert ="INSERT INTO Battle(battle_type,attacker_size,defender_size,location,region,attacker_outcome) VALUES(%s,%s,%s,%s,%s,%s)"
    cursor = connection.cursor()
    cursor.executemany(mysql_insert, results)
    connection.commit()
    return {
        'statusCode': 200,
        'body': json.dumps('Hello from Lambda!')
    }
